# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("index_eg_hf_cons.csv")

# %%
df.head()
# Out:
#    Unnamed: 0         Raison Sociale      SIREN  Année  Note   Structure  \
# 0           0  AUTOGRILL COTE FRANCE  391378239   2020  73.0  Entreprise
# 1           1  AUTOGRILL COTE FRANCE  391378239   2019  88.0  Entreprise
# 2           2  AUTOGRILL COTE FRANCE  391378239   2018  88.0  Entreprise
# 3           3                ESTERRA  455501452   2020   NaN  Entreprise
# 4           4                ESTERRA  455501452   2019   NaN  Entreprise
#
#    Nom UES Entreprises UES (SIREN)                      Région  \
# 0      NaN                     NaN  Provence-Alpes-Côte d'Azur
# 1      NaN                     NaN  Provence-Alpes-Côte d'Azur
# 2      NaN                     NaN  Provence-Alpes-Côte d'Azur
# 3      NaN                     NaN             Hauts-de-France
# 4      NaN                     NaN             Hauts-de-France
#
#         Département  ...  id_1  \
# 0  Bouches-du-Rhône  ...     I
# 1  Bouches-du-Rhône  ...     I
# 2  Bouches-du-Rhône  ...     I
# ...

# %%
df[df["Année"] == 2019].groupby("label_1").mean("Note").sort_values("Note")
# Out:
#                                                       Unnamed: 0  \
# label_1
# Industries extractives                               6864.272727
# Construction                                         8370.129693
# Production et distribution d'électricité, de ga...   8785.736842
# Enseignement                                         9054.684211
# Industrie manufacturière                             9022.975380
# Activités spécialisées, scientifiques et techni...   9179.392638
# Production et distribution d'eau ; assainisseme...   8212.967213
# Arts, spectacles et activités récréatives           10437.045455
# Commerce ; réparation d'automobiles et de motoc...   8780.750294
# Information et communication                         9169.620339
# Agriculture, sylviculture et pêche                  10776.941176
# Activités de services administratifs et de soutien   9379.061475
# Activités financières et d'assurance                 9853.167116
# ...
